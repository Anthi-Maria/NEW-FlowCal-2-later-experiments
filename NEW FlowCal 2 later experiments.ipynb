# %%
pip install FlowCal
# Out:
# Requirement already satisfied: FlowCal in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (1.3.0)
# Requirement already satisfied: pandas>=0.23.0 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from FlowCal) (1.2.3)
# Requirement already satisfied: openpyxl>=2.2.0 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from FlowCal) (3.1.2)
# Requirement already satisfied: six>=1.10.0 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from FlowCal) (1.15.0)
# Requirement already satisfied: scipy>=0.19.0 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from FlowCal) (1.9.1)
# Requirement already satisfied: packaging>=16.8 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from FlowCal) (20.9)
# Requirement already satisfied: numpy>=1.9.0 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from FlowCal) (1.23.4)
# Requirement already satisfied: scikit-image>=0.10.0 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from FlowCal) (0.20.0)
# Requirement already satisfied: xlrd<2.0.0,>=0.9.2 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from FlowCal) (1.2.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from FlowCal) (3.7.2)
# Requirement already satisfied: scikit-learn>=0.16.0 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from FlowCal) (1.2.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from matplotlib>=2.0.0->FlowCal) (10.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from matplotlib>=2.0.0->FlowCal) (4.39.3)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from matplotlib>=2.0.0->FlowCal) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from matplotlib>=2.0.0->FlowCal) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from matplotlib>=2.0.0->FlowCal) (2.8.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from matplotlib>=2.0.0->FlowCal) (5.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from matplotlib>=2.0.0->FlowCal) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from matplotlib>=2.0.0->FlowCal) (1.0.7)
# Requirement already satisfied: zipp>=3.1.0 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=2.0.0->FlowCal) (3.4.1)
# Requirement already satisfied: et-xmlfile in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from openpyxl>=2.2.0->FlowCal) (1.1.0)
# Requirement already satisfied: pytz>=2017.3 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from pandas>=0.23.0->FlowCal) (2021.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from scikit-image>=0.10.0->FlowCal) (1.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from scikit-image>=0.10.0->FlowCal) (2023.3.21)
# Requirement already satisfied: networkx>=2.8 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from scikit-image>=0.10.0->FlowCal) (3.0)
# Requirement already satisfied: lazy_loader>=0.1 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from scikit-image>=0.10.0->FlowCal) (0.2)
# Requirement already satisfied: imageio>=2.4.1 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from scikit-image>=0.10.0->FlowCal) (2.27.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from scikit-learn>=0.16.0->FlowCal) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/schwartzlab/miniconda3/lib/python3.8/site-packages (from scikit-learn>=0.16.0->FlowCal) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import FlowCal

s = FlowCal.io.FCSData('04-blank-A2-1.fcs')
print(s.shape)
# Out:
# (137793, 26)

# %%
print(s.channels)
# Out:
# ('FSC-H', 'FSC-A', 'SSC-H', 'SSC-A', 'FL1-H', 'FL1-A', 'FL2-H', 'FL2-A', 'FL3-H', 'FL3-A', 'FL4-H', 'FL4-A', 'FL5-H', 'FL5-A', 'FL6-H', 'FL6-A', 'FL7-H', 'FL7-A', 'FL8-H', 'FL8-A', 'FL9-H', 'FL9-A', 'FL10-H', 'FL10-A', 'FSC-Width', 'Time')

# %%
import matplotlib.pyplot as plt
plt.hist(s[:, 'FL1-H'], bins=100)
plt.show()

# %%
s_transformed = FlowCal.transform.to_rfi(s, channels='FL1-H')
s_transformed
# Out:
# FCSData([[ 1.08947998e+04,  1.85655000e+04,  1.25880000e+04, ...,
#            7.59000015e+01,  1.74601025e+03,  3.98000000e+02],
#          [ 1.13407002e+04,  2.23380005e+03,  6.90400000e+03, ...,
#            1.41699997e+02,  2.01710663e+02,  7.18000000e+02],
#          [ 1.20959004e+04,  7.85370020e+03,  1.31537998e+04, ...,
#           -1.05099998e+02,  6.65244202e+02,  1.26800000e+03],
#          ...,
#          [ 2.38091992e+04,  2.06908008e+04,  2.78390000e+04, ...,
#            3.87999992e+01,  8.89892456e+02,  2.99996000e+06],
#          [ 1.20502998e+04,  6.95900024e+02,  1.22862998e+04, ...,
#           -6.90000000e+01,  5.90703850e+01,  2.99997100e+06],
#          [ 1.05080000e+04,  1.12082002e+04,  8.84450000e+03, ...,
#            6.76999969e+01,  1.09258191e+03,  2.99998100e+06]])

# %%
import numpy as np
bins = np.logspace(0, 4, 100)
plt.hist(s_transformed[:, 'FL1-H'], bins=bins)
plt.xscale('log')
plt.show()

# %%
s = FlowCal.io.FCSData('04-blank-A2-1.fcs')
s = FlowCal.transform.to_rfi(s)

FlowCal.plot.hist1d(s, channel='FL1-H')
plt.show()

# %%
FlowCal.plot.hist1d(s, channel='FL1-H', xscale='log', bins=1024)
plt.show()

# %%
filenames = ['04-blank-A2-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-A3-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-A4-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-A5-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-A6-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-A7-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-A8-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-A9-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-A10-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-A11-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-C2-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-C3-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-C4-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-C5-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-C6-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-C7-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-C8-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-C9-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-C10-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-C11-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-E2-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-E3-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-E4-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-E5-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-E6-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-E7-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-E8-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-E9-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-E10-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-E11-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-G2-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-G3-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-G4-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-G5-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-G6-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-G7-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-G8-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-G9-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-G10-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-G11-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-G9-1.fcs']
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['04-blank-G6-1.fcs']
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()
